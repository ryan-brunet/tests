# %%
import numpy as np

# check how numpy.dot() works
a = np.array([[2,1,5],[3,1,1], [4,5,1]])
b = np.array([[1],[2],[3]])
print(a)
print(b)
print(np.shape(a))
print(np.shape(b))
# Out:
# [[2 1 5]
#  [3 1 1]
#  [4 5 1]]
# [[1]
#  [2]
#  [3]]
# (3, 3)
# (3, 1)

# %%
c = a.T.dot(b)
print(c)
# Out:
# [[8]
#  [3]]

# %%
d = a*b
print(d)
# Out:
# [[ 2  1  5]
#  [ 6  2  2]
#  [12 15  3]]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(b.type)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'
