# %% [markdown]
# ## Alternative mass-flux distribution
# Use the exponentially modified Gaussian as an alternative functional form to the mass-flux distribution $\frac{dM}{d\psi}$ used in PM04. First consider the basic form (see [wiki](https://en.wikipedia.org/wiki/Exponentially_modified_Gaussian_distribution) entry):

# %%
import numpy as np
from scipy import special
from matplotlib import pyplot as plt
from scipy.integrate import simpson

# set parameters
x = np.linspace(0,1,200)
mu = 0.0 # location of knee
mu_erf = 0.0# location of inflection point of erfc
sigma = 0.01 # halflife/width of exp
sigma_erf = 0.1 # width of erfc
lmb = 2
lmb_erf = 1
# lmb_0 = 2

# define exponentially modified Gaussian
def exp_normal_dist(x,mu,sigma,lmb, mu_erf,sigma_erf,lmb_erf):
    var = sigma**2
    var_erf = sigma_erf**2
    return 0.5*lmb_erf*np.exp(lmb/2*(2*mu+lmb*var - 2*x))*special.erfc((mu_erf + lmb_erf*var_erf - x)/(np.sqrt(2)*sigma_erf))

# Normalise function
f = exp_normal_dist(x,mu, sigma,lmb,mu_erf,sigma_erf,lmb_erf)
area = simpson(f,x)

norm_f = f/area

exp_func = np.exp(0.5*lmb*(2*mu + lmb*sigma**2 - 2*x))
erfc_func = special.erfc((mu_erf + lmb_erf*sigma_erf**2 - x)/(np.sqrt(2)*sigma_erf))

# plot
fig,ax = plt.subplots()
ax.plot(x, f, label="EMG(x)")
ax.plot(x, exp_func, alpha = 0.2, label="exp(x)")
ax.plot(x, erfc_func, alpha = 0.2, label = "erfc(x)")
ax.set(xlabel="x", ylabel="f(x)", ylim=[0,5])
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$
#     f(x;\mu,\sigma,\lambda) = \frac{\lambda}{2}e^{\frac{\lambda}{2}(2\mu + \lambda\sigma^2 - 2x)}\mathrm{erfc}\left(\frac{\mu + \lambda\sigma^2 - x}{\sqrt{2}\sigma}\right)
# $$
#
#
# Now consider the function scaled to the relevant astrophysical parameters, and plot alongside the distribution from PM04:

# %%
B_star = 1e8
R_star = 1e4
cs = 1e6
G = 6.67e-11
M_sol = 1.989e30
M_star = 1.4*M_sol
psi_star = B_star*R_star**2/2
ma = 1e-5*M_sol
x0 = cs**2*R_star*R_star/G/M_star
bratio = 10
psi_0 = np.sqrt(cs*cs*ma/x0**3)
# print(psi_0,psi_star,ma,x0)

MUMAX = 1.
MUMIN = 0.
nth = 128
n_contours = nth - 1
dmu = np.abs(MUMAX-MUMIN)/(nth-1.0)
mu_levels = np.empty(n_contours)

for i in range(0,n_contours):
    contour_mesh_value = (n_contours - i)/(n_contours + 1.0)/dmu
    mu_levels[i] = contour_mesh_value*dmu

# psi_levels = (psi_star/psi_0)*(1-mu_levels*mu_levels)
# psi_levels = np.append(0,psi_levels)

psi_levels = np.linspace(0,1,100)*psi_star/psi_0

# EMG parameters
mu = psi_levels[10]*psi_0/psi_star
sigma = 0.3 # width of exponential
lmb = 10 # half-life / decay rate

mu_erfc = 0.2*mu # position of peak
sigma_erfc = 0.2*mu # width of peak
lmb_erfc = 10 # position of peak and height
# lmb_0 = 10
print(mu_erfc)

dmdpsi_pm04 = 0.5*psi_0/psi_star*bratio*np.exp(-bratio*psi_levels*psi_0/psi_star)/(1.0 - np.exp(-bratio))
dmdpsi_emg = exp_normal_dist(psi_levels*psi_0/psi_star, mu,sigma, lmb,mu_erfc,sigma_erfc,lmb_erfc)

exp_func = np.exp(0.5*lmb*(2*mu + lmb*sigma**2 - 2*psi_levels*psi_0/psi_star))
erfc_func = 0.5*lmb_erfc*special.erfc((mu_erfc + lmb_erfc*sigma_erfc**2 - psi_levels*psi_0/psi_star)/(np.sqrt(2)*sigma_erfc))

# normalise EMG to match same area as PM04
norm_pm04 = simpson(dmdpsi_pm04,psi_levels)*ma/M_sol*2
norm_emg = simpson(dmdpsi_emg,psi_levels)*ma/M_sol*2

norm_dmdpsi_emg = dmdpsi_emg*norm_pm04/norm_emg
print(norm_pm04/norm_emg)
norm_exp_func = exp_func*norm_pm04/norm_emg
norm_erfc_func = erfc_func*dmdpsi_pm04[10]#*norm_pm04/norm_emg

fig,ax = plt.subplots()
ax.plot(psi_levels*psi_0/psi_star, dmdpsi_pm04, alpha = 0.6, label="PM04")
ax.plot(psi_levels*psi_0/psi_star, norm_dmdpsi_emg, alpha = 0.6, label="EMG")
ax.plot(psi_levels*psi_0/psi_star, norm_exp_func, '--', alpha = 0.1, label="exp(x)")
ax.plot(psi_levels*psi_0/psi_star, norm_erfc_func, '--', alpha = 0.1, label = "erfc(x)")
# ax.plot(psi_levels, exp_func_2, alpha = 0.2, label="exp(x) 2")
ax.plot(psi_levels[10]*psi_0/psi_star, norm_erfc_func[10], '.r')
ax.set_ylim(bottom = -1, top=1.2*np.max(dmdpsi_pm04))
ax.set(xlabel=r"$\psi/\psi_*$", ylabel=r"$d\tilde{M}/d\tilde{\psi}$")
plt.legend()
plt.show()
# Out:
# 0.020202020202020207
# 5.794444443946397
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# calculate mass inside profile
print(f"PM04 mass = {norm_pm04}")
area_emg_dmdpsi = simpson(norm_dmdpsi_emg, psi_levels)*ma/M_sol*2
print(f"EMG mass = {area_emg_dmdpsi}")
# Out:
# PM04 mass = 1.0000005774250421e-05
# EMG mass = 1.000000577425042e-05

# %%
x_0 = 2
a = 3
x = np.linspace(0,5,200)
y = special.erfc(a*(x-x_0))


fig,ax = plt.subplots()
ax.plot(x,y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Model:**
# $f(x, \mu, \sigma, \lambda; \mu_{erfc}, \sigma_{erfc}, \lambda_{erfc}; \lambda_0) = \frac{\lambda_0}{2}e^{-\lambda\left[x - \left(\mu + \frac{\lambda\sigma^2}{2}\right)\right]}\mathrm{erfc}\left[{-\frac{x - \left(\mu_{erfc} + \lambda_{erfc}\sigma_{erfc}^2\right)}{\sqrt{2}\sigma_{erfc}}}\right]$
#
# **Variables to consider:**
#
# **exponential:**
# $\mu$, $\sigma$, $\lambda$
#
# **erfc:**
# $\mu_{erfc}$, $\sigma_{erfc}$, $\lambda_{erfc}$
#
# **overall sign:**
# $\lambda_{0}$ > 0
#
# **Close to PM04:**
# - $\mu_{erfc}$ < 0
# - $0 < \sigma_{erfc} < 1$ (small) so that the step is sharp, and does not affect the exponential at x>0
# - $\mu \approx 1$
# - $\lambda > 1$
#
# **Transformation:**
# 1. bring mu_erfc closer to zero/small positive
# 2. slowly increase sigma_erfc to widen the bump that begins
# 3. move mu_erfc larger, until dmdpsi connects at 0 (or widen by increasing sigma_erfc, such that there is a non-zero dmdpsi at x = 0)
# 4. increase both until the max is in the middle, after which we need to effect the 'switch', flipping both te exp and the erfc around
# 5. flip exp by setting lamba < 0
# 6. simultaneously flip erfc by setting sigma_erfc < 0
# 7. now continue increasing mu_erfc to near psi_star
# 8. increase it past psi_star until the shape resembles Lane Emden

# %%
mass = dmdpsi_pm04[:-1]*(psi_levels[1:]-psi_levels[:-1])
fig,ax= plt.subplots()
# ax.plot(psi_levels*psi_0/psi_star, dmdpsi_pm04,'.')
ax.plot(psi_levels[:-1]*psi_0/psi_star, mass, '.-', alpha = 0.4)
plt.show()

print(np.sum(mass)*2)
delta_m_1 = mass[0]*0.2
mass[0] -= delta_m_1
mass[1] += delta_m_1
delta_m_2 = mass[1]*0.1
mass[1] -= delta_m_2
mass[2] += delta_m_2
delta_m_3 = mass[1]*0.05
mass[2] -= delta_m_3
mass[3] += delta_m_3
fig,ax= plt.subplots()
# ax.plot(psi_levels*psi_0/psi_star, dmdpsi_pm04,'.')
ax.plot(psi_levels[:-1]*psi_0/psi_star, mass, '.-', alpha = 0.4)
plt.show()

print(np.sum(mass)*2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 1.0513551593295114
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 1.0513551593295114

# %% [markdown]
# Try the Fujisawa (2022) profile:
#
# $\frac{dM}{d\psi} = \frac{K}{\cosh\left(\frac{\psi - \psi_{\rm ref}}{\psi_a}\right)}$

# %%
K = 1
psi_ref = 0.2
psi_a = 0.1
dmdpsi_fujisawa = K/np.cosh((psi_levels*psi_0/psi_star - psi_ref)/psi_a)

fig,ax = plt.subplots()
ax.plot(psi_levels*psi_0/psi_star, dmdpsi_fujisawa, '.-', alpha=0.4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
# plot PM04 dmdpsi for two different masses
ma_1 = 1.e-8
ma_2 = 9.e-8

F0_1 = cs*cs*ma_1*M_sol/x0/x0/x0
F0_2 = cs*cs*ma_2*M_sol/x0**3
psi_01 = np.sqrt(F0_1)
psi_02 = np.sqrt(F0_2)
print(psi_01,psi_02)
n_contours = 128
MUMAX = 1
MUMIN = 0

mu_levels = np.empty(n_contours)
for i in range(n_contours):
    mu_levels[i] = (n_contours - i)*MUMAX/(n_contours+1.) + (1 + i)/(n_contours+1.)*MUMIN
    
psi_levels = (psi_star/psi_0)*(1-mu_levels*mu_levels)

psi_levels_1 = psi_levels * psi_0 / psi_01
psi_levels_2 = psi_levels * psi_0 / psi_02

pm04_dmdpsi_01 = 0.5*psi_01/psi_star*bratio*np.exp(-bratio*psi_levels_1*psi_01/psi_star)/(1.0-np.exp(-bratio))
pm04_dmdpsi_02 = 0.5*psi_02/psi_star*bratio*np.exp(-bratio*psi_levels_2*psi_02/psi_star)/(1.0-np.exp(-bratio))


fig,ax = plt.subplots()
ax.plot(psi_levels_1/psi_levels_1[-1], pm04_dmdpsi_01*ma_1/psi_01, '.-', label="1")
ax.plot(psi_levels_2/psi_levels_2[-1], pm04_dmdpsi_02*ma_2/psi_02, '.-', label="2")
ax.plot(psi_levels_1/psi_levels_1[-1], (pm04_dmdpsi_01*ma_2/ma_1)*ma_1/psi_01, '.', label="1")
ax.legend()
plt.show()
# Out:
# 3.5698533091583296e+17 1.0709559927474988e+18
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
