# %%
import numpy as np

# unique_indices = np.array([ 45,  46,  50,  51,  52,  54,  55,  60,  61 , 62 , 68,  69 , 70 , 74 , 75 , 76,  83,  84,
  # 85,  90,  91,  95,  96, 101, 102, 107, 120, 121, 122, 123, 124, 125, 126])
unique_indices = np.array([3,4,6,7,8])
diffs = np.diff(unique_indices)
print(diffs)
breaks = np.where(diffs!=1)[0] + 1
print(breaks)
breaks = np.concatenate(([0],breaks,[len(unique_indices)]))
interval_starts = unique_indices[breaks[:-1]]
interval_lengths = np.diff(breaks)
print(breaks)
print(interval_starts)
print(interval_lengths)
# Out:
# [1 2 1 1]
# [2]
# [0 2 5]
# [3 6]
# [2 3]

# %%
fluxtube_mass_b2 = np.ones(9)
region_masses = np.array([np.sum(fluxtube_mass_b2[interval_starts[i]-1:interval_starts[i] + interval_lengths[i]]) for i in range(len(interval_lengths))])
adjusted_region_mass = region_masses/(interval_lengths + 1)
print(region_masses)
print(adjusted_region_mass)
# Out:
# [3. 4.]
# [1. 1.]

# %%
adjusted_mass = np.zeros_like(fluxtube_mass_b2)
for i in range(len(interval_starts)):
    index_test_start = interval_starts[i]-1
    index_test_end = interval_starts[i] + interval_lengths[i]
    print(index_test_start,index_test_end)
    adjusted_mass[interval_starts[i]-1:interval_starts[i] + interval_lengths[i]] = adjusted_region_mass[i] - fluxtube_mass_b2[interval_starts[i]-1:interval_starts[i] + interval_lengths[i]]
# Out:
# 2 5
# 5 9
